# %%
% matplotlib inline
from __future__ import print_function
import random

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
# from sklearn import datasets, linear_model
import statsmodels.api as sm

# %%
def polynomials(X, degree=1):
    # See also numpy.vander
    array = [X]
    y = X
    for i in range(2, int(degree + 1)):
        y = y * X
        array.append(y)
    return np.array(array).transpose()

# %%
X = np.array(range(10))
# X = np.array([2, 2, 3])
polynomials(X, 6)
# Out:
# array([[  2,   4,   8,  16,  32,  64],
#        [  2,   4,   8,  16,  32,  64],
#        [  3,   9,  27,  81, 243, 729]])

# %%
def monomials(X, degree=1):
    y = np.array(X)
    y = np.power(X, degree)
    return np.array([y]).transpose()

# %%
X = np.array(range(10))
# X = np.array([2, 2, 3])
monomials(X, 4)
# Out:
# array([[   0],
#        [   1],
#        [  16],
#        [  81],
#        [ 256],
#        [ 625],
#        [1296],
#        [2401],
#        [4096],
#        [6561]])

# %%
def generate_data(func, a, b, n=100):
    data = []
    for _ in range(n):
        x = random.random() * (b - a)
        y = func(x)
        data.append((x, y))
    return list(sorted(data))

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
# norm = np.random.normal(mu, sigma)

# Generate some data
f = lambda x: 4 + 5 * x - 3 * x*x + 0.1 * x * x * x + np.random.normal(mu, sigma)
data = generate_data(f, 0, 2, n=20)
data
# Out:
# [(0.0024406883449217265, 4.09927017019386),
#  (0.021386904260020767, 4.00426318201055),
#  (0.04719560416519708, 4.303689387372753),
#  (0.1256839150867144, 4.5320587182700836),
#  (0.35225184099989715, 5.372439515247091),
#  (0.558681559571256, 6.045032462762441),
#  (0.5954176992107356, 5.841278923580499),
#  (0.6171132183347057, 6.0633238355937955),
#  (0.7778411628099937, 6.072840133632192),
#  (0.8656478469651316, 6.394980686464329),
#  (1.0006730526956322, 6.072825476276065),
#  (1.2221673698991116, 5.940004257036399),
#  (1.3222700216603485, 5.521298401018892),
#  (1.4005626037946004, 5.325006381653265),
#  (1.6705602018472638, 4.425907687804267),
#  (1.7595686051460648, 3.9794837200205313),
#  (1.7843864479975138, 3.9323109755065597),
#  (1.8025687095678207, 4.020469372829586),
#  (1.819913999547684, 4.007687142940167),
#  (1.9842339385925323, 2.89954811827394)]

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

# %%
for i in range(1, 10):
    X = monomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     29.23
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.23e-05
# Time:                        10:47:06   Log-Likelihood:                -51.420
# No. Observations:                  20   AIC:                             104.8
# Df Residuals:                      19   BIC:                             105.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.2988      0.610      5.407      0.000         2.022     4.576
# ==============================================================================
# Omnibus:                        4.762   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                2.518
# Skew:                          -0.625   Prob(JB):                        0.284
# Kurtosis:                       1.793   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 3.84
# Bias: -0.983066784409
# Variance: 4.81767432841
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     13.07
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):            0.00185
# Time:                        10:47:06   Log-Likelihood:                -55.502
# No. Observations:                  20   AIC:                             113.0
# Df Residuals:                      19   BIC:                             114.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.6513      0.457      3.615      0.002         0.695     2.607
# ==============================================================================
# Omnibus:                        3.521   Durbin-Watson:                   0.047
# Prob(Omnibus):                  0.172   Jarque-Bera (JB):                2.650
# Skew:                          -0.762   Prob(JB):                        0.266
# Kurtosis:                       2.075   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 7.78
# Bias: 2.8746903502
# Variance: 4.89347499468
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     8.345
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):            0.00941
# Time:                        10:47:07   Log-Likelihood:                -57.095
# No. Observations:                  20   AIC:                             116.2
# Df Residuals:                      19   BIC:                             117.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.8154      0.282      2.889      0.009         0.225     1.406
# ==============================================================================
# Omnibus:                        3.376   Durbin-Watson:                   0.049
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                2.785
# Skew:                          -0.859   Prob(JB):                        0.248
# Kurtosis:                       2.377   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 10.61
# Bias: 6.23441100068
# Variance: 4.36845593237
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     6.237
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0219
# Time:                        10:47:07   Log-Likelihood:                -57.897
# No. Observations:                  20   AIC:                             117.8
# Df Residuals:                      19   BIC:                             118.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.4072      0.163      2.497      0.022         0.066     0.748
# ==============================================================================
# Omnibus:                        3.999   Durbin-Watson:                   0.051
# Prob(Omnibus):                  0.135   Jarque-Bera (JB):                3.113
# Skew:                          -0.955   Prob(JB):                        0.211
# Kurtosis:                       2.708   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 12.52
# Bias: 8.62450452255
# Variance: 3.89023248729
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     5.051
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0367
# Time:                        10:47:07   Log-Likelihood:                -58.378
# No. Observations:                  20   AIC:                             118.8
# Df Residuals:                      19   BIC:                             119.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.2050      0.091      2.248      0.037         0.014     0.396
# ==============================================================================
# Omnibus:                        5.175   Durbin-Watson:                   0.053
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                3.712
# Skew:                          -1.054   Prob(JB):                        0.156
# Kurtosis:                       3.083   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 13.89
# Bias: 10.367540686
# Variance: 3.51309794618
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     4.275
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0526
# Time:                        10:47:07   Log-Likelihood:                -58.707
# No. Observations:                  20   AIC:                             119.4
# Df Residuals:                      19   BIC:                             120.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.1035      0.050      2.068      0.053        -0.001     0.208
# ==============================================================================
# Omnibus:                        6.766   Durbin-Watson:                   0.056
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                4.681
# Skew:                          -1.158   Prob(JB):                       0.0963
# Kurtosis:                       3.505   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 14.94
# Bias: 11.7225029004
# Variance: 3.21049475461
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     3.710
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0692
# Time:                        10:47:07   Log-Likelihood:                -58.952
# No. Observations:                  20   AIC:                             119.9
# Df Residuals:                      19   BIC:                             120.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0523      0.027      1.926      0.069        -0.005     0.109
# ==============================================================================
# Omnibus:                        8.638   Durbin-Watson:                   0.059
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                6.110
# Skew:                          -1.265   Prob(JB):                       0.0471
# Kurtosis:                       3.966   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 15.81
# Bias: 12.8412071498
# Variance: 2.95699745349
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     3.268
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0865
# Time:                        10:47:08   Log-Likelihood:                -59.149
# No. Observations:                  20   AIC:                             120.3
# Df Residuals:                      19   BIC:                             121.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0263      0.015      1.808      0.086        -0.004     0.057
# ==============================================================================
# Omnibus:                       10.659   Durbin-Watson:                   0.061
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                8.050
# Skew:                          -1.373   Prob(JB):                       0.0179
# Kurtosis:                       4.455   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 16.56
# Bias: 13.8097071582
# Variance: 2.7357941172
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     2.905
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.105
# Time:                        10:47:08   Log-Likelihood:                -59.313
# No. Observations:                  20   AIC:                             120.6
# Df Residuals:                      19   BIC:                             121.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0132      0.008      1.705      0.105        -0.003     0.029
# ==============================================================================
# Omnibus:                       12.711   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               10.494
# Skew:                          -1.481   Prob(JB):                      0.00526
# Kurtosis:                       4.956   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 17.22
# Bias: 14.6769360035
# Variance: 2.5365750815

# %%
bs = []
vars = []
exps = np.arange(0, 10, 0.1)

for i in exps:
    X = monomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    bs.append(bias)
    vars.append(var)

plt.plot(exps, bs, label="Bias")
plt.plot(exps, vars, label="Variance")
ax = plt.gca()

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)

plt.show()

# %%
for i in range(1, 10):
    X = polynomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     29.23
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.23e-05
# Time:                        10:52:29   Log-Likelihood:                -51.420
# No. Observations:                  20   AIC:                             104.8
# Df Residuals:                      19   BIC:                             105.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.2988      0.610      5.407      0.000         2.022     4.576
# ==============================================================================
# Omnibus:                        4.762   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                2.518
# Skew:                          -0.625   Prob(JB):                        0.284
# Kurtosis:                       1.793   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 3.84
# Bias: -0.983066784409
# Variance: 4.81767432841
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     65.64
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           5.39e-09
# Time:                        10:52:30   Log-Likelihood:                -39.582
# No. Observations:                  20   AIC:                             83.16
# Df Residuals:                      18   BIC:                             85.16
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            12.7325      1.517      8.393      0.000         9.545    15.920
# x2            -5.9156      0.926     -6.388      0.000        -7.861    -3.970
# ==============================================================================
# Omnibus:                        4.398   Durbin-Watson:                   0.082
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                3.494
# Skew:                           1.012   Prob(JB):                        0.174
# Kurtosis:                       2.688   Cond. No.                         9.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1.57
# Bias: -3.28660363912
# Variance: 4.84512809152
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.887
# Method:                 Least Squares   F-statistic:                     53.23
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           7.48e-09
# Time:                        10:52:30   Log-Likelihood:                -37.324
# No. Observations:                  20   AIC:                             80.65
# Df Residuals:                      17   BIC:                             83.64
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            19.6814      3.627      5.426      0.000        12.028    27.334
# x2           -17.5365      5.665     -3.096      0.007       -29.488    -5.585
# x3             4.3167      2.080      2.075      0.053        -0.072     8.706
# ==============================================================================
# Omnibus:                        8.744   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                6.763
# Skew:                           1.401   Prob(JB):                       0.0340
# Kurtosis:                       3.511   Cond. No.                         75.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1.37
# Bias: -2.84926639564
# Variance: 4.20560580733
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                     45.30
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.57e-08
# Time:                        10:52:30   Log-Likelihood:                -35.619
# No. Observations:                  20   AIC:                             79.24
# Df Residuals:                      16   BIC:                             83.22
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            31.2012      7.511      4.154      0.001        15.279    47.124
# x2           -50.2971     19.740     -2.548      0.021       -92.143    -8.451
# x3            31.8920     16.111      1.979      0.065        -2.263    66.047
# x4            -7.1446      4.143     -1.724      0.104       -15.928     1.638
# ==============================================================================
# Omnibus:                       10.740   Durbin-Watson:                   0.211
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                8.386
# Skew:                           1.498   Prob(JB):                       0.0151
# Kurtosis:                       4.044   Cond. No.                         549.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1.26
# Bias: -2.48781021738
# Variance: 3.7347303407
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     42.05
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.66e-08
# Time:                        10:52:30   Log-Likelihood:                -33.644
# No. Observations:                  20   AIC:                             77.29
# Df Residuals:                      15   BIC:                             82.27
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            49.4869     12.305      4.022      0.001        23.259    75.715
# x2          -127.5905     46.521     -2.743      0.015      -226.748   -28.433
# x3           140.5556     61.891      2.271      0.038         8.637   272.474
# x4           -69.1740     34.485     -2.006      0.063      -142.676     4.328
# x5            12.4082      6.854      1.810      0.090        -2.202    27.018
# ==============================================================================
# Omnibus:                       13.711   Durbin-Watson:                   0.339
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               11.717
# Skew:                           1.594   Prob(JB):                      0.00286
# Kurtosis:                       4.974   Cond. No.                     3.42e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 1.17
# Bias: -2.07927648467
# Variance: 3.23623689876
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     41.27
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.11e-08
# Time:                        10:52:31   Log-Likelihood:                -31.458
# No. Observations:                  20   AIC:                             74.92
# Df Residuals:                      14   BIC:                             80.89
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            72.5187     16.897      4.292      0.001        36.278   108.759
# x2          -282.6917     94.331     -2.997      0.010      -485.012   -80.372
# x3           490.2264    197.619      2.481      0.026        66.375   914.078
# x4          -416.2846    190.414     -2.186      0.046      -824.681    -7.888
# x5           169.2747     85.066      1.990      0.066       -13.174   351.723
# x6           -26.4044     14.279     -1.849      0.086       -57.029     4.220
# ==============================================================================
# Omnibus:                       19.398   Durbin-Watson:                   0.450
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.702
# Skew:                           1.897   Prob(JB):                     1.94e-05
# Kurtosis:                       6.412   Cond. No.                     2.40e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 1.11
# Bias: -1.74896732551
# Variance: 2.84647481149
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     37.18
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.33e-07
# Time:                        10:52:31   Log-Likelihood:                -30.281
# No. Observations:                  20   AIC:                             74.56
# Df Residuals:                      13   BIC:                             81.53
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            91.0736     22.031      4.134      0.001        43.479   138.668
# x2          -475.5138    177.246     -2.683      0.019      -858.431   -92.597
# x3          1134.4721    541.291      2.096      0.056       -34.917  2303.861
# x4         -1400.1339    794.245     -1.763      0.101     -3115.996   315.729
# x5           927.1946    600.580      1.544      0.147      -370.279  2224.668
# x6          -312.9975    225.340     -1.389      0.188      -799.815   173.820
# x7            42.2743     33.175      1.274      0.225       -29.396   113.945
# ==============================================================================
# Omnibus:                       22.495   Durbin-Watson:                   0.544
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.323
# Skew:                           2.024   Prob(JB):                     2.60e-07
# Kurtosis:                       7.473   Cond. No.                     1.76e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 1.08
# Bias: -1.55012016676
# Variance: 2.62196095212
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     34.59
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.88e-07
# Time:                        10:52:31   Log-Likelihood:                -28.930
# No. Observations:                  20   AIC:                             73.86
# Df Residuals:                      12   BIC:                             81.83
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           114.7276     27.959      4.103      0.001        53.809   175.646
# x2          -803.5930    302.899     -2.653      0.021     -1463.553  -143.633
# x3          2576.7078   1214.790      2.121      0.055       -70.093  5223.508
# x4         -4382.8567   2392.240     -1.832      0.092     -9595.099   829.386
# x5          4230.0492   2574.195      1.643      0.126     -1378.640  9838.738
# x6         -2327.4214   1544.671     -1.507      0.158     -5692.970  1038.127
# x7           680.1041    485.215      1.402      0.186      -377.089  1737.297
# x8           -81.8780     62.149     -1.317      0.212      -217.289    53.533
# ==============================================================================
# Omnibus:                       27.146   Durbin-Watson:                   0.665
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.935
# Skew:                           2.277   Prob(JB):                     6.43e-11
# Kurtosis:                       8.965   Cond. No.                     1.18e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 1.06
# Bias: -1.38731051086
# Variance: 2.43915743511
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     31.94
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.27e-06
# Time:                        10:52:31   Log-Likelihood:                -27.730
# No. Observations:                  20   AIC:                             73.46
# Df Residuals:                      11   BIC:                             82.42
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           144.4157     37.208      3.881      0.003        62.522   226.309
# x2         -1347.7644    547.529     -2.462      0.032     -2552.868  -142.661
# x3          5731.3635   2918.843      1.964      0.075      -692.967  1.22e+04
# x4         -1.309e+04   7717.830     -1.696      0.118     -3.01e+04  3896.734
# x5          1.747e+04   1.15e+04      1.524      0.156     -7753.196  4.27e+04
# x6         -1.404e+04      1e+04     -1.404      0.188     -3.61e+04  7976.519
# x7          6682.5432   5089.502      1.313      0.216     -4519.376  1.79e+04
# x8         -1734.3035   1396.266     -1.242      0.240     -4807.464  1338.857
# x9           188.9891    159.539      1.185      0.261      -162.154   540.132
# ==============================================================================
# Omnibus:                       31.709   Durbin-Watson:                   0.721
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.633
# Skew:                           2.608   Prob(JB):                     5.60e-15
# Kurtosis:                      10.181   Cond. No.                     1.01e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 1.05
# Bias: -1.23754188668
# Variance: 2.27458550419

# %%
bs = []
vars = []
exps = np.arange(0, 12, .1)

for i in exps:
    X = polynomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    bs.append(bias)
    vars.append(var)

plt.plot(exps, bs, label="Bias")
plt.plot(exps, vars, label="Variance")
ax = plt.gca()

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)

plt.show()

# %%
# f = lambda x: 1 - 2 * x + 3 * x ** degree + np.random.normal(mu, sigma)
# my_data = generate_data(f, 0, 2, n=20)

# %%
for degree in range(1, 7):
    # Generate some data
    f = lambda x: 1 - 2 * x + 3 * x ** degree + np.random.normal(mu, sigma)
    data = generate_data(f, 0, 2, n=20)

    domain = np.array([x[0] for x in data])
    Y = np.array([x[1] for x in data])

    X = np.array([domain]).transpose()
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()
    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
    # Compute the errors

    # Plot outputs
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     353.9
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           9.66e-14
# Time:                        11:03:29   Log-Likelihood:                -13.911
# No. Observations:                  20   AIC:                             29.82
# Df Residuals:                      19   BIC:                             30.82
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.7571      0.093     18.813      0.000         1.562     1.953
# ==============================================================================
# Omnibus:                        1.442   Durbin-Watson:                   0.185
# Prob(Omnibus):                  0.486   Jarque-Bera (JB):                0.887
# Skew:                           0.020   Prob(JB):                        0.642
# Kurtosis:                       1.969   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.40
# Bias: -0.601753185893
# Variance: 0.988911563535
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     273.1
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           9.89e-13
# Time:                        11:03:29   Log-Likelihood:                -27.473
# No. Observations:                  20   AIC:                             56.95
# Df Residuals:                      19   BIC:                             57.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.2610      0.197     16.526      0.000         2.848     3.674
# ==============================================================================
# Omnibus:                        1.140   Durbin-Watson:                   0.161
# Prob(Omnibus):                  0.565   Jarque-Bera (JB):                0.971
# Skew:                           0.329   Prob(JB):                        0.615
# Kurtosis:                       2.144   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 6.04
# Bias: 2.02950069725
# Variance: 4.00405213793
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     101.7
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.60e-09
# Time:                        11:03:29   Log-Likelihood:                -53.070
# No. Observations:                  20   AIC:                             108.1
# Df Residuals:                      19   BIC:                             109.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             6.2402      0.619     10.084      0.000         4.945     7.535
# ==============================================================================
# Omnibus:                        4.653   Durbin-Watson:                   0.156
# Prob(Omnibus):                  0.098   Jarque-Bera (JB):                2.980
# Skew:                           0.935   Prob(JB):                        0.225
# Kurtosis:                       3.283   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 36.83
# Bias: 23.9760558153
# Variance: 12.8446405928
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     86.17
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.72e-08
# Time:                        11:03:29   Log-Likelihood:                -70.036
# No. Observations:                  20   AIC:                             142.1
# Df Residuals:                      19   BIC:                             143.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            13.0066      1.401      9.283      0.000        10.074    15.939
# ==============================================================================
# Omnibus:                        5.216   Durbin-Watson:                   0.127
# Prob(Omnibus):                  0.074   Jarque-Bera (JB):                3.254
# Skew:                           0.958   Prob(JB):                        0.196
# Kurtosis:                       3.481   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 194.20
# Bias: 131.136324401
# Variance: 63.0552335199
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     16.87
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           0.000600
# Time:                        11:03:29   Log-Likelihood:                -84.622
# No. Observations:                  20   AIC:                             171.2
# Df Residuals:                      19   BIC:                             172.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            15.1524      3.690      4.107      0.001         7.430    22.875
# ==============================================================================
# Omnibus:                       41.080   Durbin-Watson:                   0.508
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              126.289
# Skew:                           3.283   Prob(JB):                     3.77e-28
# Kurtosis:                      13.413   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 443.14
# Bias: 378.754554487
# Variance: 64.3802077274
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                     20.54
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           0.000228
# Time:                        11:03:30   Log-Likelihood:                -98.318
# No. Observations:                  20   AIC:                             198.6
# Df Residuals:                      19   BIC:                             199.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            30.4430      6.717      4.532      0.000        16.384    44.502
# ==============================================================================
# Omnibus:                       32.365   Durbin-Watson:                   0.331
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.233
# Skew:                           2.720   Prob(JB):                     6.84e-15
# Kurtosis:                       9.977   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1823.19
# Bias: 1530.5535999
# Variance: 292.624436872

# %%
for degree in range(1, 7):
    # Generate some data
    f = lambda x: 1 - 2 * x + 3 * x ** degree + np.random.normal(mu, sigma)
    data = generate_data(f, 0, 2, n=20)

    domain = np.array([x[0] for x in data])
    Y = np.array([x[1] for x in data])

    for i in range(1, 5):
        X = polynomials(domain, i)
        # Create linear regression object
        regr = sm.OLS(Y, X).fit()

        yhat = regr.predict(X)
        sse = np.mean((np.mean(yhat) - Y) ** 2)
        var = np.var(yhat)
        bias = sse - var - 0.01

        # The coefficients
        print(regr.summary())

        # The mean square error
        print("Residual sum of squares: %.2f" % sse)

        print("Bias: {bias}".format(bias=bias))
        print("Variance: {var}".format(var=var))

        # Plot outputs
        plt.scatter(domain, Y,  color='black')
        plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

        plt.title("n = " + str(i))

        plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     221.2
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           6.40e-12
# Time:                        11:13:49   Log-Likelihood:                -17.113
# No. Observations:                  20   AIC:                             36.23
# Df Residuals:                      19   BIC:                             37.22
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.7507      0.118     14.871      0.000         1.504     1.997
# ==============================================================================
# Omnibus:                       10.222   Durbin-Watson:                   0.053
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):                2.050
# Skew:                          -0.015   Prob(JB):                        0.359
# Kurtosis:                       1.432   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.64
# Bias: -0.743018192799
# Variance: 1.37112161018
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     160.5
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.35e-12
# Time:                        11:13:49   Log-Likelihood:                -13.125
# No. Observations:                  20   AIC:                             30.25
# Df Residuals:                      18   BIC:                             32.24
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.1750      0.490      6.484      0.000         2.146     4.204
# x2            -0.9326      0.314     -2.970      0.008        -1.592    -0.273
# ==============================================================================
# Omnibus:                        4.305   Durbin-Watson:                   0.098
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                2.123
# Skew:                           0.517   Prob(JB):                        0.346
# Kurtosis:                       1.784   Cond. No.                         10.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.57
# Bias: -0.551448056953
# Variance: 1.11532311101
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     134.9
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.73e-12
# Time:                        11:13:49   Log-Likelihood:                -10.374
# No. Observations:                  20   AIC:                             26.75
# Df Residuals:                      17   BIC:                             29.74
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             5.4024      1.056      5.117      0.000         3.175     7.630
# x2            -4.8035      1.692     -2.839      0.011        -8.373    -1.234
# x3             1.5150      0.653      2.320      0.033         0.137     2.893
# ==============================================================================
# Omnibus:                        2.648   Durbin-Watson:                   0.185
# Prob(Omnibus):                  0.266   Jarque-Bera (JB):                2.148
# Skew:                           0.703   Prob(JB):                        0.342
# Kurtosis:                       2.224   Cond. No.                         73.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.55
# Bias: -0.440420060448
# Variance: 0.982266578683
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     125.1
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           7.43e-12
# Time:                        11:13:49   Log-Likelihood:                -7.7374
# No. Observations:                  20   AIC:                             23.47
# Df Residuals:                      16   BIC:                             27.46
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             8.9498      1.875      4.772      0.000         4.974    12.925
# x2           -16.3842      5.488     -2.985      0.009       -28.019    -4.750
# x3            12.2995      4.944      2.488      0.024         1.819    22.780
# x4            -3.0462      1.386     -2.197      0.043        -5.985    -0.107
# ==============================================================================
# Omnibus:                        2.439   Durbin-Watson:                   0.270
# Prob(Omnibus):                  0.295   Jarque-Bera (JB):                1.985
# Skew:                           0.726   Prob(JB):                        0.371
# Kurtosis:                       2.478   Cond. No.                         511.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.54
# Bias: -0.3515946431
# Variance: 0.881135628044
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     254.9
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.83e-12
# Time:                        11:13:50   Log-Likelihood:                -20.688
# No. Observations:                  20   AIC:                             43.38
# Df Residuals:                      19   BIC:                             44.37
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             2.8401      0.178     15.964      0.000         2.468     3.212
# ==============================================================================
# Omnibus:                        6.836   Durbin-Watson:                   0.271
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                4.882
# Skew:                           1.193   Prob(JB):                       0.0871
# Kurtosis:                       3.404   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 3.14
# Bias: 1.04064196107
# Variance: 2.0865973435
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     518.5
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.23e-16
# Time:                        11:13:50   Log-Likelihood:                -6.6616
# No. Observations:                  20   AIC:                             17.32
# Df Residuals:                      18   BIC:                             19.31
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.6408      0.310      2.070      0.053        -0.010     1.291
# x2             1.6979      0.229      7.429      0.000         1.218     2.178
# ==============================================================================
# Omnibus:                        2.688   Durbin-Watson:                   0.256
# Prob(Omnibus):                  0.261   Jarque-Bera (JB):                1.395
# Skew:                           0.634   Prob(JB):                        0.498
# Kurtosis:                       3.258   Cond. No.                         7.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 3.13
# Bias: -0.322304591759
# Variance: 3.44322034275
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     588.6
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.28e-17
# Time:                        11:13:50   Log-Likelihood:               -0.84246
# No. Observations:                  20   AIC:                             7.685
# Df Residuals:                      17   BIC:                             10.67
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             2.2609      0.502      4.501      0.000         1.201     3.321
# x2            -1.6731      0.937     -1.786      0.092        -3.650     0.303
# x3             1.4966      0.409      3.663      0.002         0.635     2.359
# ==============================================================================
# Omnibus:                       25.810   Durbin-Watson:                   0.432
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.212
# Skew:                           2.244   Prob(JB):                     1.85e-09
# Kurtosis:                       8.302   Cond. No.                         42.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 3.12
# Bias: -0.184714916409
# Variance: 3.29536190605
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     487.7
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.72e-16
# Time:                        11:13:50   Log-Likelihood:                0.74482
# No. Observations:                  20   AIC:                             6.510
# Df Residuals:                      16   BIC:                             10.49
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.8645      1.078      3.583      0.002         1.578     6.151
# x2            -7.8301      3.817     -2.051      0.057       -15.922     0.261
# x3             7.9745      3.924      2.032      0.059        -0.344    16.293
# x4            -2.0196      1.217     -1.659      0.117        -4.600     0.561
# ==============================================================================
# Omnibus:                       32.478   Durbin-Watson:                   0.560
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.487
# Skew:                           2.696   Prob(JB):                     2.21e-15
# Kurtosis:                      10.205   Cond. No.                         355.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 3.12
# Bias: -0.148918068135
# Variance: 3.25805906301
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     90.13
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.21e-08
# Time:                        11:13:50   Log-Likelihood:                -54.664
# No. Observations:                  20   AIC:                             111.3
# Df Residuals:                      19   BIC:                             112.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             6.6654      0.702      9.494      0.000         5.196     8.135
# ==============================================================================
# Omnibus:                        2.969   Durbin-Watson:                   0.128
# Prob(Omnibus):                  0.227   Jarque-Bera (JB):                2.393
# Skew:                           0.812   Prob(JB):                        0.302
# Kurtosis:                       2.515   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 45.77
# Bias: 28.9248512705
# Variance: 16.8311801869
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     923.4
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           7.28e-19
# Time:                        11:13:51   Log-Likelihood:                -25.740
# No. Observations:                  20   AIC:                             55.48
# Df Residuals:                      18   BIC:                             57.47
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -5.2179      0.700     -7.459      0.000        -6.688    -3.748
# x2             7.5215      0.430     17.512      0.000         6.619     8.424
# ==============================================================================
# Omnibus:                        5.699   Durbin-Watson:                   0.182
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                1.623
# Skew:                          -0.014   Prob(JB):                        0.444
# Kurtosis:                       1.605   Cond. No.                         9.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 44.67
# Bias: -2.1936031318
# Variance: 46.8544371615
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     5707.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.01e-25
# Time:                        11:13:51   Log-Likelihood:                -2.9856
# No. Observations:                  20   AIC:                             11.97
# Df Residuals:                      17   BIC:                             14.96
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             2.0041      0.636      3.151      0.006         0.662     3.346
# x2            -4.1694      0.970     -4.299      0.000        -6.216    -2.123
# x3             4.2408      0.348     12.184      0.000         3.506     4.975
# ==============================================================================
# Omnibus:                       12.004   Durbin-Watson:                   0.524
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.641
# Skew:                           1.414   Prob(JB):                      0.00806
# Kurtosis:                       4.890   Cond. No.                         73.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 44.61
# Bias: -0.723030228303
# Variance: 45.3202663676
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     5934.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.81e-25
# Time:                        11:13:51   Log-Likelihood:                0.88431
# No. Observations:                  20   AIC:                             6.231
# Df Residuals:                      16   BIC:                             10.21
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             4.1903      0.961      4.359      0.000         2.152     6.228
# x2           -10.8469      2.564     -4.230      0.001       -16.283    -5.411
# x3            10.1824      2.181      4.669      0.000         5.559    14.806
# x4            -1.6004      0.582     -2.750      0.014        -2.834    -0.367
# ==============================================================================
# Omnibus:                       19.532   Durbin-Watson:                   0.677
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.125
# Skew:                           1.768   Prob(JB):                     5.77e-06
# Kurtosis:                       7.055   Cond. No.                         461.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 44.60
# Bias: -0.486978705516
# Variance: 45.0816696046
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     95.47
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           7.63e-09
# Time:                        11:13:51   Log-Likelihood:                -74.639
# No. Observations:                  20   AIC:                             151.3
# Df Residuals:                      19   BIC:                             152.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            15.5939      1.596      9.771      0.000        12.254    18.934
# ==============================================================================
# Omnibus:                        6.189   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                2.074
# Skew:                           0.379   Prob(JB):                        0.354
# Kurtosis:                       1.616   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 305.27
# Bias: 221.820659723
# Variance: 83.4404462732
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     853.2
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.47e-18
# Time:                        11:13:52   Log-Likelihood:                -46.975
# No. Observations:                  20   AIC:                             97.95
# Df Residuals:                      18   BIC:                             99.94
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           -17.0138      2.033     -8.369      0.000       -21.285   -12.743
# x2            18.9764      1.159     16.377      0.000        16.542    21.411
# ==============================================================================
# Omnibus:                        3.050   Durbin-Watson:                   0.158
# Prob(Omnibus):                  0.218   Jarque-Bera (JB):                1.384
# Skew:                          -0.247   Prob(JB):                        0.501
# Kurtosis:                       1.809   Cond. No.                         11.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 297.10
# Bias: -8.05845378428
# Variance: 305.151617741
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.020e+04
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           9.60e-34
# Time:                        11:13:52   Log-Likelihood:                -1.7051
# No. Observations:                  20   AIC:                             9.410
# Df Residuals:                      17   BIC:                             12.40
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             6.6964      0.639     10.473      0.000         5.347     8.045
# x2           -17.6624      0.937    -18.844      0.000       -19.640   -15.685
# x3            12.7485      0.323     39.436      0.000        12.066    13.431
# ==============================================================================
# Omnibus:                        0.834   Durbin-Watson:                   0.478
# Prob(Omnibus):                  0.659   Jarque-Bera (JB):                0.711
# Skew:                           0.091   Prob(JB):                        0.701
# Kurtosis:                       2.095   Cond. No.                         101.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 296.93
# Bias: 0.603619798974
# Variance: 296.317368906
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.652e+05
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.06e-36
# Time:                        11:13:52   Log-Likelihood:                 13.687
# No. Observations:                  20   AIC:                            -19.37
# Df Residuals:                      16   BIC:                            -15.39
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             2.5612      0.621      4.127      0.001         1.246     3.877
# x2            -6.1471      1.570     -3.916      0.001        -9.475    -2.820
# x3             3.1908      1.258      2.536      0.022         0.523     5.858
# x4             2.4367      0.318      7.654      0.000         1.762     3.112
# ==============================================================================
# Omnibus:                        7.736   Durbin-Watson:                   1.335
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                5.173
# Skew:                           1.141   Prob(JB):                       0.0753
# Kurtosis:                       3.999   Cond. No.                         725.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 296.93
# Bias: -0.302793614261
# Variance: 297.223624534
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     27.36
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.76e-05
# Time:                        11:13:53   Log-Likelihood:                -84.964
# No. Observations:                  20   AIC:                             171.9
# Df Residuals:                      19   BIC:                             172.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            18.6959      3.574      5.231      0.000        11.215    26.177
# ==============================================================================
# Omnibus:                       20.415   Durbin-Watson:                   0.262
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.800
# Skew:                           2.060   Prob(JB):                     1.12e-05
# Kurtosis:                       6.223   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 563.65
# Bias: 461.975249631
# Variance: 101.66617781
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     155.2
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.45e-12
# Time:                        11:13:53   Log-Likelihood:                -64.843
# No. Observations:                  20   AIC:                             133.7
# Df Residuals:                      18   BIC:                             135.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           -29.5277      4.663     -6.332      0.000       -39.324   -19.731
# x2            33.2584      3.080     10.799      0.000        26.788    39.729
# ==============================================================================
# Omnibus:                        2.533   Durbin-Watson:                   0.421
# Prob(Omnibus):                  0.282   Jarque-Bera (JB):                1.521
# Skew:                          -0.412   Prob(JB):                        0.467
# Kurtosis:                       1.930   Cond. No.                         7.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 540.54
# Bias: 9.76862399086
# Variance: 530.757857175
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     2414.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.50e-22
# Time:                        11:13:53   Log-Likelihood:                -33.317
# No. Observations:                  20   AIC:                             72.63
# Df Residuals:                      17   BIC:                             75.62
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            18.0606      2.633      6.860      0.000        12.506    23.616
# x2           -47.7057      4.201    -11.356      0.000       -56.569   -38.843
# x3            30.4502      1.561     19.512      0.000        27.158    33.743
# ==============================================================================
# Omnibus:                        5.056   Durbin-Watson:                   0.535
# Prob(Omnibus):                  0.080   Jarque-Bera (JB):                1.828
# Skew:                          -0.327   Prob(JB):                        0.401
# Kurtosis:                       1.672   Cond. No.                         56.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 539.00
# Bias: 5.99794657749
# Variance: 532.995343133
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.498e+04
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.52e-32
# Time:                        11:13:53   Log-Likelihood:               -0.60646
# No. Observations:                  20   AIC:                             9.213
# Df Residuals:                      16   BIC:                             13.20
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.8342      1.006      0.829      0.419        -1.298     2.966
# x2             4.6954      2.736      1.716      0.105        -1.104    10.495
# x3           -16.3575      2.346     -6.973      0.000       -21.330   -11.385
# x4            12.6788      0.630     20.135      0.000        11.344    14.014
# ==============================================================================
# Omnibus:                        1.821   Durbin-Watson:                   0.726
# Prob(Omnibus):                  0.402   Jarque-Bera (JB):                0.984
# Skew:                           0.020   Prob(JB):                        0.611
# Kurtosis:                       1.914   Cond. No.                         363.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 538.97
# Bias: -0.525338849258
# Variance: 539.490218567
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.611
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     29.89
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.83e-05
# Time:                        11:13:54   Log-Likelihood:                -85.757
# No. Observations:                  20   AIC:                             173.5
# Df Residuals:                      19   BIC:                             174.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            21.2248      3.882      5.467      0.000        13.099    29.350
# ==============================================================================
# Omnibus:                       18.955   Durbin-Watson:                   0.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.256
# Skew:                           1.924   Prob(JB):                     3.99e-05
# Kurtosis:                       6.082   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 604.92
# Bias: 472.373968775
# Variance: 132.53260858
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     92.19
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.48e-10
# Time:                        11:13:54   Log-Likelihood:                -71.010
# No. Observations:                  20   AIC:                             146.0
# Df Residuals:                      18   BIC:                             148.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           -38.4896      7.901     -4.871      0.000       -55.090   -21.890
# x2            43.4451      5.578      7.788      0.000        31.725    55.165
# ==============================================================================
# Omnibus:                        0.942   Durbin-Watson:                   0.305
# Prob(Omnibus):                  0.624   Jarque-Bera (JB):                0.738
# Skew:                           0.035   Prob(JB):                        0.692
# Kurtosis:                       2.062   Cond. No.                         8.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 589.30
# Bias: 27.7050740704
# Variance: 561.581859798
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     925.7
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           5.01e-19
# Time:                        11:13:54   Log-Likelihood:                -44.188
# No. Observations:                  20   AIC:                             94.38
# Df Residuals:                      17   BIC:                             97.36
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            29.5759      4.953      5.971      0.000        19.125    40.026
# x2           -83.1906      8.457     -9.836      0.000      -101.034   -65.347
# x3            52.8328      3.472     15.215      0.000        45.507    60.159
# ==============================================================================
# Omnibus:                        2.519   Durbin-Watson:                   0.473
# Prob(Omnibus):                  0.284   Jarque-Bera (JB):                1.355
# Skew:                           0.310   Prob(JB):                        0.508
# Kurtosis:                       1.885   Cond. No.                         55.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 586.54
# Bias: 12.4424189811
# Variance: 574.08501363
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.158e+04
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.82e-27
# Time:                        11:13:54   Log-Likelihood:                -15.496
# No. Observations:                  20   AIC:                             38.99
# Df Residuals:                      16   BIC:                             42.97
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -4.8244      2.435     -1.981      0.065        -9.986     0.337
# x2            35.3956      7.562      4.681      0.000        19.364    51.427
# x3           -63.5979      7.190     -8.845      0.000       -78.840   -48.356
# x4            34.5595      2.119     16.308      0.000        30.067    39.052
# ==============================================================================
# Omnibus:                        0.704   Durbin-Watson:                   0.404
# Prob(Omnibus):                  0.703   Jarque-Bera (JB):                0.687
# Skew:                           0.168   Prob(JB):                        0.709
# Kurtosis:                       2.157   Cond. No.                         379.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 586.48
# Bias: -2.24977123824
# Variance: 588.719143459

# %%
import math
f = lambda x: math.exp(x)
data = generate_data(f, 0, 5, n=40)

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

# %%
for i in range(1, 10):
    X = monomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     129.3
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           5.92e-14
# Time:                        11:39:00   Log-Likelihood:                -178.55
# No. Observations:                  40   AIC:                             359.1
# Df Residuals:                      39   BIC:                             360.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            13.9448      1.226     11.373      0.000        11.465    16.425
# ==============================================================================
# Omnibus:                       35.482   Durbin-Watson:                   0.104
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.902
# Skew:                           2.348   Prob(JB):                     3.66e-19
# Kurtosis:                       8.375   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1246.24
# Bias: 827.145785117
# Variance: 419.084207172
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     466.8
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.62e-23
# Time:                        11:39:00   Log-Likelihood:                -156.54
# No. Observations:                  40   AIC:                             315.1
# Df Residuals:                      39   BIC:                             316.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.9802      0.184     21.606      0.000         3.608     4.353
# ==============================================================================
# Omnibus:                       35.079   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.315
# Skew:                           2.294   Prob(JB):                     2.98e-19
# Kurtosis:                       8.491   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1223.60
# Bias: 363.000004371
# Variance: 860.58544102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     1929.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           7.92e-35
# Time:                        11:39:01   Log-Likelihood:                -129.37
# No. Observations:                  40   AIC:                             260.7
# Df Residuals:                      39   BIC:                             262.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.9760      0.022     43.924      0.000         0.931     1.021
# ==============================================================================
# Omnibus:                       17.709   Durbin-Watson:                   0.199
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.694
# Skew:                           1.294   Prob(JB):                     4.34e-06
# Kurtosis:                       5.849   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1211.37
# Bias: 86.4332896426
# Variance: 1124.92743768
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     8965.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.04e-47
# Time:                        11:39:01   Log-Likelihood:                -98.958
# No. Observations:                  40   AIC:                             199.9
# Df Residuals:                      39   BIC:                             201.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.2245      0.002     94.685      0.000         0.220     0.229
# ==============================================================================
# Omnibus:                        6.130   Durbin-Watson:                   0.114
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.006
# Skew:                          -0.759   Prob(JB):                       0.0818
# Kurtosis:                       2.165   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1212.61
# Bias: -62.9756774384
# Variance: 1275.57978906
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     3244.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.68e-39
# Time:                        11:39:01   Log-Likelihood:                -119.14
# No. Observations:                  40   AIC:                             240.3
# Df Residuals:                      39   BIC:                             242.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0497      0.001     56.953      0.000         0.048     0.052
# ==============================================================================
# Omnibus:                       14.664   Durbin-Watson:                   0.051
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.270
# Skew:                          -1.255   Prob(JB):                     0.000293
# Kurtosis:                       4.861   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1222.56
# Bias: -135.838043588
# Variance: 1358.39210261
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     1105.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.17e-30
# Time:                        11:39:01   Log-Likelihood:                -140.23
# No. Observations:                  40   AIC:                             282.5
# Df Residuals:                      39   BIC:                             284.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0107      0.000     33.234      0.000         0.010     0.011
# ==============================================================================
# Omnibus:                       16.935   Durbin-Watson:                   0.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.843
# Skew:                          -1.353   Prob(JB):                     2.98e-05
# Kurtosis:                       5.277   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1238.81
# Bias: -158.518612671
# Variance: 1397.31448463
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     558.5
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.01e-24
# Time:                        11:39:01   Log-Likelihood:                -153.21
# No. Observations:                  40   AIC:                             308.4
# Df Residuals:                      39   BIC:                             310.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0023    9.6e-05     23.633      0.000         0.002     0.002
# ==============================================================================
# Omnibus:                        9.054   Durbin-Watson:                   0.112
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.256
# Skew:                          -0.874   Prob(JB):                       0.0161
# Kurtosis:                       4.377   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1259.74
# Bias: -146.766856788
# Variance: 1406.49466128
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                     347.8
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.97e-21
# Time:                        11:39:02   Log-Likelihood:                -161.91
# No. Observations:                  40   AIC:                             325.8
# Df Residuals:                      39   BIC:                             327.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0005   2.54e-05     18.649      0.000         0.000     0.001
# ==============================================================================
# Omnibus:                        3.442   Durbin-Watson:                   0.117
# Prob(Omnibus):                  0.179   Jarque-Bera (JB):                2.217
# Skew:                          -0.458   Prob(JB):                        0.330
# Kurtosis:                       3.701   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1283.70
# Bias: -112.227081836
# Variance: 1395.91730044
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     244.8
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.11e-18
# Time:                        11:39:02   Log-Likelihood:                -168.10
# No. Observations:                  40   AIC:                             338.2
# Df Residuals:                      39   BIC:                             339.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1          9.763e-05   6.24e-06     15.647      0.000       8.5e-05     0.000
# ==============================================================================
# Omnibus:                        0.841   Durbin-Watson:                   0.116
# Prob(Omnibus):                  0.657   Jarque-Bera (JB):                0.241
# Skew:                          -0.138   Prob(JB):                        0.886
# Kurtosis:                       3.262   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1309.01
# Bias: -64.1497276097
# Variance: 1373.14863935

# %%
f = lambda x: math.sin(x)
data = generate_data(f, 0, 5, n=40)

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

# %%
for i in range(1, 10):
    X = monomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.2175
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.644
# Time:                        11:40:23   Log-Likelihood:                -42.884
# No. Observations:                  40   AIC:                             87.77
# Df Residuals:                      39   BIC:                             89.46
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0214      0.046      0.466      0.644        -0.071     0.114
# ==============================================================================
# Omnibus:                        5.238   Durbin-Watson:                   0.043
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                4.456
# Skew:                          -0.722   Prob(JB):                        0.108
# Kurtosis:                       2.234   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.47
# Bias: 0.463299052495
# Variance: 0.000791463228991
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.563
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.219
# Time:                        11:40:23   Log-Likelihood:                -42.210
# No. Observations:                  40   AIC:                             86.42
# Df Residuals:                      39   BIC:                             88.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -0.0160      0.013     -1.250      0.219        -0.042     0.010
# ==============================================================================
# Omnibus:                        7.563   Durbin-Watson:                   0.034
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                3.741
# Skew:                          -0.514   Prob(JB):                        0.154
# Kurtosis:                       1.911   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.58
# Bias: 0.558367702372
# Variance: 0.00990194248606
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     4.719
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0360
# Time:                        11:40:24   Log-Likelihood:                -40.711
# No. Observations:                  40   AIC:                             83.42
# Df Residuals:                      39   BIC:                             85.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -0.0067      0.003     -2.172      0.036        -0.013    -0.000
# ==============================================================================
# Omnibus:                       21.379   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.100
# Skew:                          -0.321   Prob(JB):                        0.129
# Kurtosis:                       1.569   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.62
# Bias: 0.5710437138
# Variance: 0.0350549103185
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     6.816
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0128
# Time:                        11:40:24   Log-Likelihood:                -39.774
# No. Observations:                  40   AIC:                             81.55
# Df Residuals:                      39   BIC:                             83.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -0.0019      0.001     -2.611      0.013        -0.003    -0.000
# ==============================================================================
# Omnibus:                       31.075   Durbin-Watson:                   0.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.302
# Skew:                          -0.251   Prob(JB):                        0.116
# Kurtosis:                       1.474   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.62
# Bias: 0.554021743679
# Variance: 0.0547826832045
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     7.635
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):            0.00869
# Time:                        11:40:24   Log-Likelihood:                -39.420
# No. Observations:                  40   AIC:                             80.84
# Df Residuals:                      39   BIC:                             82.53
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -0.0004      0.000     -2.763      0.009        -0.001    -0.000
# ==============================================================================
# Omnibus:                       25.790   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.166
# Skew:                          -0.277   Prob(JB):                        0.125
# Kurtosis:                       1.519   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.61
# Bias: 0.533521537491
# Variance: 0.0651797040722
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     7.646
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):            0.00865
# Time:                        11:40:24   Log-Likelihood:                -39.415
# No. Observations:                  40   AIC:                             80.83
# Df Residuals:                      39   BIC:                             82.52
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1         -9.725e-05   3.52e-05     -2.765      0.009        -0.000 -2.61e-05
# ==============================================================================
# Omnibus:                       19.956   Durbin-Watson:                   0.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.046
# Skew:                          -0.328   Prob(JB):                        0.132
# Kurtosis:                       1.587   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.60
# Bias: 0.517009294567
# Variance: 0.0687352429765
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.136
# Method:                 Least Squares   F-statistic:                     7.289
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0102
# Time:                        11:40:25   Log-Likelihood:                -39.569
# No. Observations:                  40   AIC:                             81.14
# Df Residuals:                      39   BIC:                             82.83
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1         -2.058e-05   7.62e-06     -2.700      0.010      -3.6e-05 -5.16e-06
# ==============================================================================
# Omnibus:                       16.152   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                3.986
# Skew:                          -0.375   Prob(JB):                        0.136
# Kurtosis:                       1.648   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.58
# Bias: 0.505318026512
# Variance: 0.068423207008
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     6.819
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0127
# Time:                        11:40:25   Log-Likelihood:                -39.773
# No. Observations:                  40   AIC:                             81.55
# Df Residuals:                      39   BIC:                             83.23
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1         -4.268e-06   1.63e-06     -2.611      0.013     -7.57e-06 -9.62e-07
# ==============================================================================
# Omnibus:                       13.684   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                3.955
# Skew:                          -0.413   Prob(JB):                        0.138
# Kurtosis:                       1.699   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.57
# Bias: 0.497469601207
# Variance: 0.0663050336224
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     6.355
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0159
# Time:                        11:40:25   Log-Likelihood:                -39.976
# No. Observations:                  40   AIC:                             81.95
# Df Residuals:                      39   BIC:                             83.64
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1         -8.761e-07   3.48e-07     -2.521      0.016     -1.58e-06 -1.73e-07
# ==============================================================================
# Omnibus:                       12.010   Durbin-Watson:                   0.060
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                3.935
# Skew:                          -0.441   Prob(JB):                        0.140
# Kurtosis:                       1.742   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.57
# Bias: 0.492308517355
# Variance: 0.0635498132298
